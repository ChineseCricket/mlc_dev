# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Width = np.array([16,18,20,22,24,26,28,30,32,34])
Inductance = np.array([0.059203,0.059634,0.059839,0.059942,0.059990,0.060017,0.060030,0.060024,0.060034,0.060034])

# %%
plt.plot(Width/8, Inductance, '-')
plt.xlabel('Width_air/Width_coil')
plt.ylabel('Inductance (uH)')
# Out:
# Text(0, 0.5, 'Inductance (uH)')
